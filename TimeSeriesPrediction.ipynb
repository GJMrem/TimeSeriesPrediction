# %%
import pandas as pd 
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('data.csv',sep=';', parse_dates=True, index_col="REPORTDATE").sort_index()
df
# Out:
#                   VALUE
# REPORTDATE
# 2013-12-30   3457625638
# 2013-12-31   3417092149
# 2014-01-01   3417092149
# 2014-01-02   4333581643
# 2014-01-03   5010720003
# ...                 ...
# 2019-12-05  73555567407
# 2019-12-06  74062556441
# 2019-12-07  78228598454
# 2019-12-08  76917198439
# 2019-12-09  74105978838
#
# [2111 rows x 1 columns]

# %%
df = df.asfreq('D')

# %%
df.plot( figsize=(16,9))

# %%
test_size = round(0.2*len(df))

df_train = df[:-test_size]
df_test = df[-test_size:]

# %%
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['figure.figsize'] = (16, 9)

# %%
plt.plot(df_train, label='Training set')
plt.plot(df_test, label='Test set', color='orange')
plt.legend();

# %%
seasonal_decompose(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-a3a6cff3bc52> in <module>
# ----> 1 seasonal_decompose(df)
#
# c:\Users\Mikhail\Anaconda3\envs\scientificProject\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     144
#     145     if not np.all(np.isfinite(x)):
# --> 146         raise ValueError("This function does not handle missing values")
#     147     if model.startswith("m"):
#     148         if np.any(x <= 0):
#
# ValueError: This function does not handle missing values
